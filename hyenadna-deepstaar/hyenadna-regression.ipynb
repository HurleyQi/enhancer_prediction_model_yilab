# %%
# To install the needed packages, uncomment the following two lines:
print("START")
# !python3 -m pip install -r requirements.txt
# !python3 -m pip install lightning
# NOTE: Be sure to also install git lfs! Installation instructions can be found here:
# https://docs.github.com/en/repositories/working-with-files/managing-large-files/installing-git-large-file-storage?platform=mac
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/numpy-1.21.2-py3.9-linux-x86_64.egg (from -r requirements.txt (line 1)) (1.21.2)
# Requirement already satisfied: scipy in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/scipy-1.6.1-py3.9-linux-x86_64.egg (from -r requirements.txt (line 2)) (1.6.1)
# Requirement already satisfied: pandas in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: scikit-learn in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (1.2.2)
# Requirement already satisfied: matplotlib in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (3.4.3)
# Requirement already satisfied: tqdm in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (4.65.0)
# Requirement already satisfied: rich in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (13.4.2)
# Requirement already satisfied: pytorch-lightning==1.8.6 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.8.6)
# Requirement already satisfied: hydra-core in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (1.3.2)
# Requirement already satisfied: omegaconf in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: wandb in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (0.15.2)
# Requirement already satisfied: einops in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: opt_einsum in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (3.3.0)
# Requirement already satisfied: cmake in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (3.26.3)
# Requirement already satisfied: transformers in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (4.28.0)
# Requirement already satisfied: torchvision in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.14.0)
# Requirement already satisfied: timm in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (0.9.2)
# Requirement already satisfied: prettytable in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (3.8.0)
# Requirement already satisfied: numerize in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (0.12)
# Requirement already satisfied: torchtext==0.14.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (0.14.0)
# Requirement already satisfied: datasets in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (2.12.0)
# Requirement already satisfied: pyfaidx in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (0.7.2.1)
# Requirement already satisfied: polars in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.18.8)
# Requirement already satisfied: genomic-benchmarks in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (0.0.9)
# Requirement already satisfied: loguru in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (0.7.0)
# Requirement already satisfied: liftover in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (1.1.16)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (1.0.1)
# Requirement already satisfied: PyYAML>=5.4 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (5.4.1)
# Requirement already satisfied: packaging>=17.0 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (21.0)
# Requirement already satisfied: lightning-utilities!=0.4.0,>=0.3.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (0.9.0)
# Requirement already satisfied: tensorboardX>=2.2 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (2.6.1)
# Requirement already satisfied: torch>=1.9.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (1.13.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (4.5.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (2023.5.0)
# Requirement already satisfied: requests in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from torchtext==0.14.0->-r requirements.txt (line 23)) (2.30.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from torch>=1.9.0->pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from torch>=1.9.0->pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from torch>=1.9.0->pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from torch>=1.9.0->pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (11.7.99)
# Requirement already satisfied: setuptools in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.9.0->pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (58.2.0)
# Requirement already satisfied: wheel in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.9.0->pytorch-lightning==1.8.6->-r requirements.txt (line 8)) (0.37.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 3)) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from scikit-learn->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 5)) (10.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 5)) (2.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from rich->-r requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from rich->-r requirements.txt (line 7)) (2.15.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from hydra-core->-r requirements.txt (line 9)) (4.9.3)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 11)) (3.1.31)
# Requirement already satisfied: setproctitle in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 11)) (1.3.2)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 11)) (4.23.0)
# Requirement already satisfied: psutil>=5.0.0 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 11)) (5.8.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 11)) (8.1.3)
# Requirement already satisfied: appdirs>=1.4.3 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 11)) (1.4.4)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 11)) (1.22.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: pathtools in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 11)) (0.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 16)) (2023.5.5)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 16)) (0.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 16)) (0.14.1)
# Requirement already satisfied: filelock in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from transformers->-r requirements.txt (line 16)) (3.2.0)
# Requirement already satisfied: safetensors in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from timm->-r requirements.txt (line 18)) (0.3.1)
# Requirement already satisfied: wcwidth in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from prettytable->-r requirements.txt (line 19)) (0.2.5)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 24)) (0.3.6)
# Requirement already satisfied: responses<0.19 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 24)) (0.18.0)
# Requirement already satisfied: xxhash in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 24)) (3.2.0)
# Requirement already satisfied: aiohttp in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 24)) (3.8.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 24)) (12.0.0)
# Requirement already satisfied: multiprocess in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from datasets->-r requirements.txt (line 24)) (0.70.14)
# Requirement already satisfied: six in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from pyfaidx->-r requirements.txt (line 27)) (1.16.0)
# Requirement already satisfied: biopython>=1.79 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from genomic-benchmarks->-r requirements.txt (line 29)) (1.81)
# Requirement already satisfied: gdown>=4.2.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from genomic-benchmarks->-r requirements.txt (line 29)) (4.7.1)
# Requirement already satisfied: yarl in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from genomic-benchmarks->-r requirements.txt (line 29)) (1.9.2)
# Requirement already satisfied: pip>=20.0.1 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from genomic-benchmarks->-r requirements.txt (line 29)) (21.2.4)
# Requirement already satisfied: urllib3 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from liftover->-r requirements.txt (line 31)) (1.26.15)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from aiohttp->datasets->-r requirements.txt (line 24)) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from aiohttp->datasets->-r requirements.txt (line 24)) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from aiohttp->datasets->-r requirements.txt (line 24)) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from aiohttp->datasets->-r requirements.txt (line 24)) (21.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from aiohttp->datasets->-r requirements.txt (line 24)) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from aiohttp->datasets->-r requirements.txt (line 24)) (3.1.0)
# Requirement already satisfied: beautifulsoup4 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from gdown>=4.2.0->genomic-benchmarks->-r requirements.txt (line 29)) (4.12.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 11)) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 11)) (5.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from requests->torchtext==0.14.0->-r requirements.txt (line 23)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from requests->torchtext==0.14.0->-r requirements.txt (line 23)) (2021.5.30)
# Requirement already satisfied: soupsieve>1.2 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from beautifulsoup4->gdown>=4.2.0->genomic-benchmarks->-r requirements.txt (line 29)) (2.4.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from requests->torchtext==0.14.0->-r requirements.txt (line 23)) (1.7.1)
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/opt/apps/intel19/python3/3.9.7/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lightning in /home1/08537/hr8627/.local/lib/python3.9/site-packages (2.0.5)
# Requirement already satisfied: fastapi<2.0,>=0.92.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (0.100.0)
# Requirement already satisfied: packaging<25.0,>=17.1 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from lightning) (21.0)
# Requirement already satisfied: websocket-client<3.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (1.6.1)
# Requirement already satisfied: torch<4.0,>=1.11.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (1.13.0)
# Requirement already satisfied: croniter<1.5.0,>=1.3.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (1.4.1)
# Requirement already satisfied: pytorch-lightning in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (1.8.6)
# Requirement already satisfied: fsspec[http]<2025.0,>2021.06.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (2023.5.0)
# Requirement already satisfied: starsessions<2.0,>=1.2.1 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (1.3.0)
# Requirement already satisfied: uvicorn<2.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (0.23.1)
# Requirement already satisfied: starlette in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (0.27.0)
# Requirement already satisfied: pydantic<2.0.0,>=1.7.4 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (1.10.12)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from lightning) (5.4.1)
# Requirement already satisfied: urllib3<4.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (1.26.15)
# Requirement already satisfied: beautifulsoup4<6.0,>=4.8.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (4.12.2)
# Requirement already satisfied: Jinja2<5.0 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from lightning) (3.0.1)
# Requirement already satisfied: python-multipart<2.0,>=0.0.5 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (0.0.6)
# Requirement already satisfied: typing-extensions<6.0,>=4.0.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (4.5.0)
# Requirement already satisfied: inquirer<5.0,>=2.10.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (3.1.3)
# Requirement already satisfied: deepdiff<8.0,>=5.7.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (6.3.1)
# Requirement already satisfied: rich<15.0,>=12.3.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (13.4.2)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (4.65.0)
# Requirement already satisfied: websockets<13.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (11.0.3)
# Requirement already satisfied: click<10.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (8.1.3)
# Requirement already satisfied: arrow<3.0,>=1.2.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (1.2.3)
# Requirement already satisfied: dateutils<2.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (0.6.12)
# Requirement already satisfied: numpy<3.0,>=1.17.2 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages/numpy-1.21.2-py3.9-linux-x86_64.egg (from lightning) (1.21.2)
# Requirement already satisfied: requests<4.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (2.30.0)
# Requirement already satisfied: traitlets<7.0,>=5.3.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (5.9.0)
# Requirement already satisfied: lightning-cloud>=0.5.37 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (0.5.37)
# Requirement already satisfied: psutil<7.0 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from lightning) (5.8.0)
# Requirement already satisfied: backoff<4.0,>=2.2.1 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (2.2.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.7.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (0.9.0)
# Requirement already satisfied: torchmetrics<2.0,>=0.7.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7.0 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from arrow<3.0,>=1.2.0->lightning) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from beautifulsoup4<6.0,>=4.8.0->lightning) (2.4.1)
# Requirement already satisfied: pytz in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from dateutils<2.0->lightning) (2021.1)
# Requirement already satisfied: ordered-set<4.2.0,>=4.0.2 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from deepdiff<8.0,>=5.7.0->lightning) (4.1.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from fsspec[http]<2025.0,>2021.06.0->lightning) (3.8.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (1.9.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (3.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (21.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>2021.06.0->lightning) (6.0.4)
# Requirement already satisfied: python-editor>=1.0.4 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from inquirer<5.0,>=2.10.0->lightning) (1.0.4)
# Requirement already satisfied: readchar>=3.0.6 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from inquirer<5.0,>=2.10.0->lightning) (4.0.5)
# Requirement already satisfied: blessed>=1.19.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from inquirer<5.0,>=2.10.0->lightning) (1.20.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from blessed>=1.19.0->inquirer<5.0,>=2.10.0->lightning) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from blessed>=1.19.0->inquirer<5.0,>=2.10.0->lightning) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from Jinja2<5.0->lightning) (2.0.1)
# Requirement already satisfied: pyjwt in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from lightning-cloud>=0.5.37->lightning) (2.8.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from packaging<25.0,>=17.1->lightning) (2.4.7)
# Requirement already satisfied: setuptools>=41.0 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from readchar>=3.0.6->inquirer<5.0,>=2.10.0->lightning) (58.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from requests<4.0->lightning) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from requests<4.0->lightning) (3.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from rich<15.0,>=12.3.0->lightning) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from rich<15.0,>=12.3.0->lightning) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich<15.0,>=12.3.0->lightning) (0.1.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from starlette->lightning) (3.7.1)
# Requirement already satisfied: sniffio>=1.1 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette->lightning) (1.3.0)
# Requirement already satisfied: exceptiongroup in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette->lightning) (1.1.2)
# Requirement already satisfied: itsdangerous<3.0.0,>=2.0.1 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from starsessions<2.0,>=1.2.1->lightning) (2.1.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from torch<4.0,>=1.11.0->lightning) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from torch<4.0,>=1.11.0->lightning) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from torch<4.0,>=1.11.0->lightning) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from torch<4.0,>=1.11.0->lightning) (11.7.99)
# Requirement already satisfied: wheel in /opt/apps/intel19/python3/3.9.7/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch<4.0,>=1.11.0->lightning) (0.37.0)
# Requirement already satisfied: h11>=0.8 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from uvicorn<2.0->lightning) (0.14.0)
# Requirement already satisfied: tensorboardX>=2.2 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from pytorch-lightning->lightning) (2.6.1)
# Requirement already satisfied: protobuf>=4.22.3 in /home1/08537/hr8627/.local/lib/python3.9/site-packages (from tensorboardX>=2.2->pytorch-lightning->lightning) (4.23.0)
# WARNING: You are using pip version 21.2.4; however, version 23.3.1 is available.
# You should consider upgrading via the '/opt/apps/intel19/python3/3.9.7/bin/python3 -m pip install --upgrade pip' command.

# %%
# the name of the pretrained model (see possible_pretrained_names below for options), use None if 
# training from scratch
pretrained_model_name = "hyenadna-tiny-1k-seqlen" 
# path to your training data
train_data_path = '/work/09855/hurleyqi/ls6/temp/enhancer_prediction_model_yilab/tewhey_data_parser/tewhey_data_training_set'
# path to your test data
test_data_path = '/work/09855/hurleyqi/ls6/temp/enhancer_prediction_model_yilab/tewhey_data_parser/tewhey_data_testing_set'  
# number of labels (regression heads) you want to use
num_labels = 3

# the ratio of train data you want to include, where 0.0 is nothing and 1.0 is everything 
# can be made smaller to make testing faster
train_data_subset_ratio = 1.0
# the ratio of test data you want to include, where 0.0 is nothing and 1.0 is everything
# can be made smaller to make testing faster
test_data_subset_ratio = 1.0

# %%
print("checks")
# checks
import os
def is_valid_path(path):
    return os.path.exists(path)
possible_pretrained_names = ['hyenadna-tiny-1k-seqlen', 
                             'hyenadna-small-32k-seqlen', 
                             'hyenadna-medium-160k-seqlen', 
                             'hyenadna-medium-450k-seqlen', 
                             'hyenadna-large-1m-seqlen']

assert pretrained_model_name == None or \
       pretrained_model_name in possible_pretrained_names
assert is_valid_path(train_data_path)
assert is_valid_path(test_data_path)
for ratio in [train_data_subset_ratio, test_data_subset_ratio]:
    assert ratio >= 0.0 and ratio <= 1.0
assert num_labels > 0

# %%
from lightning import LightningModule
import torch
from transformers import DataCollatorWithPadding
import wandb
import evaluate
import datasets
from datasets import load_dataset
from scipy.stats import pearsonr
from torch.utils.data import DataLoader, Dataset, Subset
import torch.nn.functional as F
import torch.optim as optim
import pandas as pd
import numpy as np

# %%
# these take a little longer so they are in a separate cell
from huggingface import HyenaDNAPreTrainedModel
from standalone_hyenadna import CharacterTokenizer

# %%
class CustomDNADataset(Dataset):
    def __init__(self, csv_file, tokenizer, num_labels, max_length=1000, use_padding=True):
        self.data = pd.read_csv(csv_file)
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.use_padding = use_padding

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        sequence = self.data.iloc[idx, 0]
        label_data = []
        for i in range(num_labels):
            label_data.append(self.data.iloc[idx, i+1])

        # tokenize sequence
        tokenized_sequence = self.tokenizer(sequence, padding=self.use_padding, truncation=True, max_length=self.max_length, return_tensors="pt")
        
        sample = {'input_ids': tokenized_sequence['input_ids'][0]}
        for i, label in enumerate(label_data):
            sample[f'label{i+1}'] = torch.tensor(label)

        return sample

# %%
# Create a dataloader that only has 1/10th of the training data set
def create_subset_loader(ds, batch_size, shuffle=False, subset_fraction=1.0):
    torch.manual_seed(0)
    subset_size = int(len(ds) * subset_fraction)
    indices = list(range(len(ds)))
    np.random.shuffle(indices)
    subset_indices = indices[:subset_size]
    ds_subset = Subset(ds, subset_indices)
    train_loader = DataLoader(ds_subset, batch_size=batch_size, shuffle=shuffle)
    return train_loader

# %%
def train(model, device, train_loader, optimizer, epoch, loss_fn, num_labels, log_interval=100):
    """Training loop."""
    model.train()
    for batch_idx, batch in enumerate(train_loader):
        data = batch['input_ids'].to(device).long()
        targets_arr = []
        for i in range(num_labels):
            targets_arr.append(batch[f'label{i+1}'].to(device).float())
        optimizer.zero_grad()
        output = model(data)
        targets = torch.stack([target for target in targets_arr], dim=1)
        loss = loss_fn(output, targets)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

def test(model, device, test_loader, loss_fn, num_labels):
    """Test loop."""
    model.eval()
    test_loss = 0
    correct = 0
    all_preds = [[] for _ in range(num_labels)]
    all_labels = [[] for _ in range(num_labels)]
    with torch.no_grad():
        for batch_idx, batch in enumerate(test_loader):
            data = batch['input_ids'].to(device).long()
            targets_arr = []
            for i in range(num_labels):
                targets_arr.append(batch[f'label{i+1}'].to(device).float())
            targets = torch.stack([target for target in targets_arr], dim=1)
            output = model(data)
            test_loss += loss_fn(output, targets).item()  # sum up batch loss
            # collect all predictions and actual labels
            preds = output.detach().cpu().numpy()
            labels = targets.detach().cpu().numpy()
            for i in range(num_labels):
                all_preds[i].extend(preds[:, i])
                all_labels[i].extend(labels[:, i])

    test_loss /= len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}'.format(test_loss))
    
    # calculate and print Pearson correlation coefficient for each target
    for i in range(num_labels):
        r_value, p_value = pearsonr(np.array(all_preds[i]), np.array(all_labels[i]))
        print(f'Label {i+1} PCC: {r_value:.4f}')

# %%
import json
import os
import subprocess
import transformers
from transformers import PreTrainedModel, AutoModelForCausalLM, PretrainedConfig
import torch.nn as nn

def run_train(num_labels):
    print("start train")
    # experiment settings:
    num_epochs = 100 # ~100 seems fine
    batch_size = 256
    learning_rate = 6e-4  # good default for Hyena
    weight_decay = 0.1

    # these are used for the regression head
    use_head = True
    n_classes = num_labels

    # you can override with your own backbone config here if you want,
    # otherwise we'll load the HF one by default
    backbone_cfg = None

    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print("Using device:", device)

    # instantiate the model (pretrained here)
    if pretrained_model_name in ['hyenadna-tiny-1k-seqlen', 
                                 'hyenadna-small-32k-seqlen', 
                                 'hyenadna-medium-160k-seqlen', 
                                 'hyenadna-medium-450k-seqlen', 
                                 'hyenadna-large-1m-seqlen']:
        # use the pretrained Huggingface wrapper instead
        model = HyenaDNAPreTrainedModel.from_pretrained(
            './checkpoints',
            pretrained_model_name,
            download=False,
            config=backbone_cfg,
            device=device,
            use_head=use_head,
            n_classes=n_classes,
        )

    # from scratch
    else:
        model = HyenaDNAPreTrainedModel(**backbone_cfg, use_head=use_head, n_classes=n_classes)
        
    max_lengths = {
        'hyenadna-tiny-1k-seqlen': 1024,
        'hyenadna-small-32k-seqlen': 32768,
        'hyenadna-medium-160k-seqlen': 160000,
        'hyenadna-medium-450k-seqlen': 450000,  
        'hyenadna-large-1m-seqlen': 1_000_000,
    }

    # create tokenizer
    tokenizer = CharacterTokenizer(
        characters=['A', 'C', 'G', 'T', 'N'],  # add DNA characters, N is uncertain
        model_max_length=max_lengths[pretrained_model_name], 
        add_special_tokens=False,  # we handle special tokens elsewhere
        padding_side='left', # since HyenaDNA is causal, we pad on the left
    )

    ds_train = CustomDNADataset(train_data_path, tokenizer, max_lengths[pretrained_model_name])
    ds_test = CustomDNADataset(test_data_path, tokenizer, max_lengths[pretrained_model_name])
    
    train_loader = create_subset_loader(ds_train, batch_size, shuffle=True, subset_fraction=train_data_subset_ratio)
    test_loader = create_subset_loader(ds_test, batch_size=batch_size, shuffle=False, subset_fraction=test_data_subset_ratio)

    # loss function
    loss_fn = nn.MSELoss()

    # create optimizer
    optimizer = optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

    model.to(device)
    for epoch in range(num_epochs):
        train(model, device, train_loader, optimizer, epoch, loss_fn, num_labels)
        test(model, device, test_loader, loss_fn, num_labels)
        optimizer.step()

# %%
run_train(num_labels)
# Out:
# Using device: cuda
# pretrained model name:  ./checkpoints/hyenadna-tiny-1k-seqlen
# download val  False
# Loaded pretrained weights ok!
# Train Epoch: 0 [0/402296 (0%)]	Loss: 2.648906
# Train Epoch: 0 [25600/402296 (6%)]	Loss: 2.156297
# Train Epoch: 0 [51200/402296 (13%)]	Loss: 2.055373
# Train Epoch: 0 [76800/402296 (19%)]	Loss: 1.989709
# Train Epoch: 0 [102400/402296 (25%)]	Loss: 1.754794
# Train Epoch: 0 [128000/402296 (32%)]	Loss: 2.138357
# Train Epoch: 0 [153600/402296 (38%)]	Loss: 1.727893
# Train Epoch: 0 [179200/402296 (45%)]	Loss: 1.953629
# Train Epoch: 0 [204800/402296 (51%)]	Loss: 1.556265
# Train Epoch: 0 [230400/402296 (57%)]	Loss: 1.855148
# Train Epoch: 0 [256000/402296 (64%)]	Loss: 1.628002
# Train Epoch: 0 [281600/402296 (70%)]	Loss: 1.498039
# Train Epoch: 0 [307200/402296 (76%)]	Loss: 1.619063
# Train Epoch: 0 [332800/402296 (83%)]	Loss: 1.647242
# Train Epoch: 0 [358400/402296 (89%)]	Loss: 1.620590
# Train Epoch: 0 [384000/402296 (95%)]	Loss: 1.838758
#
# Test set: Average loss: 0.0057
# Label 1 PCC: 0.6026
# Label 2 PCC: 0.7131
# Train Epoch: 1 [0/402296 (0%)]	Loss: 1.256165
# Train Epoch: 1 [25600/402296 (6%)]	Loss: 1.433452
# Train Epoch: 1 [51200/402296 (13%)]	Loss: 1.407329
# Train Epoch: 1 [76800/402296 (19%)]	Loss: 1.282758
# Train Epoch: 1 [102400/402296 (25%)]	Loss: 1.489311
# Train Epoch: 1 [128000/402296 (32%)]	Loss: 1.421496
# Train Epoch: 1 [153600/402296 (38%)]	Loss: 1.501632
# Train Epoch: 1 [179200/402296 (45%)]	Loss: 1.436525
# Train Epoch: 1 [204800/402296 (51%)]	Loss: 1.222949
# Train Epoch: 1 [230400/402296 (57%)]	Loss: 1.393942
# Train Epoch: 1 [256000/402296 (64%)]	Loss: 1.511636
# Train Epoch: 1 [281600/402296 (70%)]	Loss: 1.192194
# Train Epoch: 1 [307200/402296 (76%)]	Loss: 1.510179
# Train Epoch: 1 [332800/402296 (83%)]	Loss: 1.452342
# Train Epoch: 1 [358400/402296 (89%)]	Loss: 1.213200
# Train Epoch: 1 [384000/402296 (95%)]	Loss: 1.420667
#
# Test set: Average loss: 0.0054
# Label 1 PCC: 0.6327
# Label 2 PCC: 0.7323
# Train Epoch: 2 [0/402296 (0%)]	Loss: 1.336380
# Train Epoch: 2 [25600/402296 (6%)]	Loss: 1.157498
# Train Epoch: 2 [51200/402296 (13%)]	Loss: 1.179636
# Train Epoch: 2 [76800/402296 (19%)]	Loss: 1.402220
# Train Epoch: 2 [102400/402296 (25%)]	Loss: 1.362155
# Train Epoch: 2 [128000/402296 (32%)]	Loss: 1.364114
# Train Epoch: 2 [153600/402296 (38%)]	Loss: 1.355018
# Train Epoch: 2 [179200/402296 (45%)]	Loss: 1.181998
# Train Epoch: 2 [204800/402296 (51%)]	Loss: 1.549805
# Train Epoch: 2 [230400/402296 (57%)]	Loss: 1.275479
# Train Epoch: 2 [256000/402296 (64%)]	Loss: 1.316201
# Train Epoch: 2 [281600/402296 (70%)]	Loss: 1.308383
# Train Epoch: 2 [307200/402296 (76%)]	Loss: 1.404778
# Train Epoch: 2 [332800/402296 (83%)]	Loss: 1.212427
# Train Epoch: 2 [358400/402296 (89%)]	Loss: 1.362983
# Train Epoch: 2 [384000/402296 (95%)]	Loss: 1.271434
#
# Test set: Average loss: 0.0052
# Label 1 PCC: 0.6509
# Label 2 PCC: 0.7444
# Train Epoch: 3 [0/402296 (0%)]	Loss: 1.285671
# Train Epoch: 3 [25600/402296 (6%)]	Loss: 1.324319
# Train Epoch: 3 [51200/402296 (13%)]	Loss: 1.240306
# Train Epoch: 3 [76800/402296 (19%)]	Loss: 1.215431
# Train Epoch: 3 [102400/402296 (25%)]	Loss: 1.258237
# Train Epoch: 3 [128000/402296 (32%)]	Loss: 1.241098
# Train Epoch: 3 [153600/402296 (38%)]	Loss: 1.369887
# Train Epoch: 3 [179200/402296 (45%)]	Loss: 1.224004
# Train Epoch: 3 [204800/402296 (51%)]	Loss: 1.420058
# Train Epoch: 3 [230400/402296 (57%)]	Loss: 1.169906
# Train Epoch: 3 [256000/402296 (64%)]	Loss: 1.374788
# Train Epoch: 3 [281600/402296 (70%)]	Loss: 1.362793
# Train Epoch: 3 [307200/402296 (76%)]	Loss: 1.146437
# Train Epoch: 3 [332800/402296 (83%)]	Loss: 1.345585
# Train Epoch: 3 [358400/402296 (89%)]	Loss: 1.235925
# Train Epoch: 3 [384000/402296 (95%)]	Loss: 1.294198
#
# Test set: Average loss: 0.0053
# Label 1 PCC: 0.6460
# Label 2 PCC: 0.7378
# Train Epoch: 4 [0/402296 (0%)]	Loss: 1.246069
# Train Epoch: 4 [25600/402296 (6%)]	Loss: 1.123611
# Train Epoch: 4 [51200/402296 (13%)]	Loss: 1.076934
# Train Epoch: 4 [76800/402296 (19%)]	Loss: 1.006726
# Train Epoch: 4 [102400/402296 (25%)]	Loss: 1.142280
# Train Epoch: 4 [128000/402296 (32%)]	Loss: 1.184381
# Train Epoch: 4 [153600/402296 (38%)]	Loss: 1.149159
# Train Epoch: 4 [179200/402296 (45%)]	Loss: 1.079186
# Train Epoch: 4 [204800/402296 (51%)]	Loss: 1.188977
# Train Epoch: 4 [230400/402296 (57%)]	Loss: 1.228810
# Train Epoch: 4 [256000/402296 (64%)]	Loss: 1.239667
# Train Epoch: 4 [281600/402296 (70%)]	Loss: 1.159713
# Train Epoch: 4 [307200/402296 (76%)]	Loss: 1.230669
# Train Epoch: 4 [332800/402296 (83%)]	Loss: 1.181529
# Train Epoch: 4 [358400/402296 (89%)]	Loss: 1.153200
# Train Epoch: 4 [384000/402296 (95%)]	Loss: 1.317783
#
# Test set: Average loss: 0.0054
# Label 1 PCC: 0.6402
# Label 2 PCC: 0.7326
# Train Epoch: 5 [0/402296 (0%)]	Loss: 0.931494
# Train Epoch: 5 [25600/402296 (6%)]	Loss: 1.075368
# Train Epoch: 5 [51200/402296 (13%)]	Loss: 0.979607
# Train Epoch: 5 [76800/402296 (19%)]	Loss: 1.059111
# Train Epoch: 5 [102400/402296 (25%)]	Loss: 1.028064
# Train Epoch: 5 [128000/402296 (32%)]	Loss: 0.953450
# Train Epoch: 5 [153600/402296 (38%)]	Loss: 1.015584
# Train Epoch: 5 [179200/402296 (45%)]	Loss: 0.984454
# Train Epoch: 5 [204800/402296 (51%)]	Loss: 1.051810
# Train Epoch: 5 [230400/402296 (57%)]	Loss: 1.071685
# Train Epoch: 5 [256000/402296 (64%)]	Loss: 0.990685
# Train Epoch: 5 [281600/402296 (70%)]	Loss: 1.081569
# Train Epoch: 5 [307200/402296 (76%)]	Loss: 0.977473
# Train Epoch: 5 [332800/402296 (83%)]	Loss: 1.001679
# Train Epoch: 5 [358400/402296 (89%)]	Loss: 1.020417
# Train Epoch: 5 [384000/402296 (95%)]	Loss: 0.960969
#
# Test set: Average loss: 0.0054
# Label 1 PCC: 0.6315
# Label 2 PCC: 0.7285
# Train Epoch: 6 [0/402296 (0%)]	Loss: 1.120999
# Train Epoch: 6 [25600/402296 (6%)]	Loss: 0.876880
# Train Epoch: 6 [51200/402296 (13%)]	Loss: 0.872738
# Train Epoch: 6 [76800/402296 (19%)]	Loss: 0.924505
# Train Epoch: 6 [102400/402296 (25%)]	Loss: 1.031817
# Train Epoch: 6 [128000/402296 (32%)]	Loss: 0.919277
# Train Epoch: 6 [153600/402296 (38%)]	Loss: 0.921902
# Train Epoch: 6 [179200/402296 (45%)]	Loss: 0.895624
# Train Epoch: 6 [204800/402296 (51%)]	Loss: 0.995123

# %%
# after getting results try with the average embedding strategy
